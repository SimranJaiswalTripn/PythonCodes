# %%
import pandas as pd
import numpy as np
from faker import Faker
import random
from datetime import datetime

# Initialize Faker
fake = Faker()

# Generate dataset
np.random.seed(42)
num_records = 1000

data = {
    "OrderID": np.arange(1, num_records + 1),
    "CustomerName": [fake.name() for _ in range(num_records)],
    "CustomerRegion": np.random.choice(["North", "South", "East", "West"], size=num_records),
    "Category": np.random.choice(["Electronics", "Clothing", "Home Appliances", "Accessories"], size=num_records),
    "Product": np.random.choice(
        ["Laptop", "Phone", "Monitor", "TV", "Blender", "Sofa", "T-Shirt", "Watch"], size=num_records
    ),
    "Price": np.random.randint(100, 1000, size=num_records),
    "Quantity": np.random.randint(1, 10, size=num_records),
    "OrderDate": pd.date_range(start="2022-01-01", periods=num_records).to_list(),
    "CustomerSatisfaction": np.random.randint(1, 6, size=num_records),  # Satisfaction scores between 1-5
}

df = pd.DataFrame(data)
df["TotalRevenue"] = df["Price"] * df["Quantity"]
df.head()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#    OrderID            CustomerName CustomerRegion         Category  Product  \
# 0        1            Michael Lang           East         Clothing  T-Shirt
# 1        2               Tracy Lee           West  Home Appliances       TV
# 2        3              Shawn Lutz          North      Electronics     Sofa
# 3        4             Tonya Price           East      Electronics    Watch
# 4        5  Cynthia Montgomery DDS           East      Electronics    Watch
#
#    Price  Quantity  OrderDate  CustomerSatisfaction  TotalRevenue
# 0    915         5 2022-01-01                     4          4575
# 1    549         6 2022-01-02                     4          3294
# 2    553         4 2022-01-03                     1          2212
# 3    728         9 2022-01-04                     3          6552
# 4    320         8 2022-01-05                     5          2560

# %%
# Calculate the total revenue generated by each product.
ProductRevenue=df.groupby("Product")["TotalRevenue"].sum()
ProductRevenue
# Out:
# Product
# Blender    360064
# Laptop     421359
# Monitor    347366
# Phone      332127
# Sofa       323841
# T-Shirt    413249
# TV         312907
# Watch      280512
# Name: TotalRevenue, dtype: int32

# %%
# Identify the region with the highest total revenue for "Clothing."
clothings=df[df["Category"]=="Clothing"]
highestregion=clothings.groupby("CustomerRegion")["TotalRevenue"].sum()
highestregion.sort_values(ascending=False).head(1)
# Out:
# CustomerRegion
# North    203861
# Name: TotalRevenue, dtype: int32

# %%
# Find the top 5 products with the highest total revenue.
# Calculate the total revenue generated by each product.
ProductRevenue=df.groupby("Product")["TotalRevenue"].sum()
ProductRevenue.sort_values(ascending=False).head(5)
# Out:
# Product
# Laptop     421359
# T-Shirt    413249
# Blender    360064
# Monitor    347366
# Phone      332127
# Name: TotalRevenue, dtype: int32

# %%
# List all orders for customers in the "North" region who purchased "Electronics."
NorthElectronics=df[(df["CustomerRegion"]=="North")&(df["Category"]=="Electronics")]
NorthElectronics
# Out:
#      OrderID          CustomerName CustomerRegion     Category  Product  \
# 2          3            Shawn Lutz          North  Electronics     Sofa
# 7          8      Alexander Haynes          North  Electronics  T-Shirt
# 21        22         Austin Hunter          North  Electronics  Monitor
# 38        39        Jesse Matthews          North  Electronics     Sofa
# 63        64           John Palmer          North  Electronics    Watch
# 74        75           Cole Murphy          North  Electronics  T-Shirt
# 82        83            Adam Green          North  Electronics  Blender
# 139      140           Denise Wood          North  Electronics    Phone
# 141      142         Sherri Murphy          North  Electronics    Phone
# 161      162       Andrea Martinez          North  Electronics  Blender
# 192      193           Alexa Ramos          North  Electronics    Phone
# 209      210           Andrew Kirk          North  Electronics   Laptop
# 215      216       Timothy Sweeney          North  Electronics    Phone
# 254      255        Jenny Figueroa          North  Electronics    Watch
# 276      277        Andrew Stewart          North  Electronics    Watch
# 278      279          Sharon Dixon          North  Electronics  Blender
# 290      291          Julia Barber          North  Electronics     Sofa
# 298      299             Mary Dean          North  Electronics  Monitor
# 362      363            Karen Cruz          North  Electronics  T-Shirt
# 377      378          Amanda Smith          North  Electronics    Watch
# 384      385         Regina Bowers          North  Electronics   Laptop
# 389      390           Rhonda Levy          North  Electronics    Phone
# 399      400         Joshua Bender          North  Electronics       TV
# 416      417          Katelyn Reid          North  Electronics     Sofa
# 430      431          Scott Holmes          North  Electronics       TV
# 440      441       Brittany Rivera          North  Electronics   Laptop
# 454      455        Kimberly Crane          North  Electronics   Laptop
# 461      462          Kayla Taylor          North  Electronics     Sofa
# 470      471     Christopher Bryan          North  Electronics       TV
# 488      489       Meghan Williams          North  Electronics       TV
# 489      490        Sherry Meadows          North  Electronics  T-Shirt
# 533      534      Michelle Fischer          North  Electronics    Phone
# 550      551          Michael Ryan          North  Electronics    Watch
# 610      611          Grace Barton          North  Electronics    Watch
# 626      627         Adam Thompson          North  Electronics    Phone
# 636      637           Holly Jones          North  Electronics  Monitor
# 675      676          Brian Weaver          North  Electronics  Blender
# 687      688            Megan Pope          North  Electronics    Phone
# 712      713  Christopher Williams          North  Electronics    Phone
# 764      765     Margaret Matthews          North  Electronics   Laptop
# 769      770         Jessica Blake          North  Electronics  Blender
# 772      773             Frank Day          North  Electronics    Watch
# 807      808         Travis Little          North  Electronics  T-Shirt
# 831      832       Deborah Parsons          North  Electronics    Phone
# 839      840      Kathleen Frazier          North  Electronics  Monitor
# 879      880        Timothy Wilson          North  Electronics    Watch
# 889      890     Nathaniel Elliott          North  Electronics  T-Shirt
# 892      893       Kathryn Sanchez          North  Electronics    Phone
# 926      927        Rachel Wallace          North  Electronics       TV
# 932      933            Mark Smith          North  Electronics   Laptop
# 944      945      Mr. Edward Costa          North  Electronics       TV
# 946      947           Joshua Moon          North  Electronics  Blender
# 961      962       Henry Alexander          North  Electronics   Laptop
# 965      966    Jacqueline Collins          North  Electronics  T-Shirt
# 966      967        Brittney Smith          North  Electronics   Laptop
# 995      996          Alicia Kelly          North  Electronics   Laptop
#
#      Price  Quantity  OrderDate  CustomerSatisfaction  TotalRevenue
# 2      553         4 2022-01-03                     1          2212
# 7      111         9 2022-01-08                     1           999
# 21     526         5 2022-01-22                     3          2630
# 38     569         7 2022-02-08                     4          3983
# 63     558         7 2022-03-05                     3          3906
# 74     397         9 2022-03-16                     3          3573
# 82     271         9 2022-03-24                     4          2439
# 139    749         2 2022-05-20                     2          1498
# 141    176         6 2022-05-22                     3          1056
# 161    630         4 2022-06-11                     3          2520
# 192    329         1 2022-07-12                     1           329
# 209    453         8 2022-07-29                     3          3624
# 215    911         9 2022-08-04                     3          8199
# 254    842         8 2022-09-12                     3          6736
# 276    934         1 2022-10-04                     4           934
# 278    801         5 2022-10-06                     4          4005
# 290    200         5 2022-10-18                     4          1000
# 298    693         1 2022-10-26                     1           693
# 362    960         8 2022-12-29                     1          7680
# 377    789         1 2023-01-13                     4           789
# 384    248         6 2023-01-20                     3          1488
# 389    982         8 2023-01-25                     2          7856
# 399    884         4 2023-02-04                     5          3536
# 416    867         1 2023-02-21                     3           867
# 430    830         3 2023-03-07                     1          2490
# 440    522         2 2023-03-17                     5          1044
# 454    799         8 2023-03-31                     1          6392
# 461    893         5 2023-04-07                     5          4465
# 470    326         8 2023-04-16                     3          2608
# 488    671         1 2023-05-04                     2           671
# 489    659         3 2023-05-05                     2          1977
# 533    327         5 2023-06-18                     4          1635
# 550    237         3 2023-07-05                     2           711
# 610    212         9 2023-09-03                     5          1908
# 626    459         9 2023-09-19                     3          4131
# 636    334         1 2023-09-29                     2           334
# 675    210         4 2023-11-07                     2           840
# 687    203         9 2023-11-19                     4          1827
# 712    308         2 2023-12-14                     1           616
# 764    261         2 2024-02-04                     1           522
# 769    159         7 2024-02-09                     2          1113
# 772    977         4 2024-02-12                     1          3908
# 807    759         5 2024-03-18                     3          3795
# 831    729         6 2024-04-11                     5          4374
# 839    401         2 2024-04-19                     4           802
# 879    369         4 2024-05-29                     4          1476
# 889    940         4 2024-06-08                     5          3760
# 892    795         4 2024-06-11                     3          3180
# 926    698         4 2024-07-15                     5          2792
# 932    483         4 2024-07-21                     3          1932
# 944    692         3 2024-08-02                     4          2076
# 946    672         9 2024-08-04                     3          6048
# 961    941         9 2024-08-19                     2          8469
# 965    121         6 2024-08-23                     1           726
# 966    211         5 2024-08-24                     2          1055
# 995    983         9 2024-09-22                     1          8847

# %%
# Calculate the average CustomerSatisfaction score for each CustomerRegion and sort the results.
Cust_Sat_Region=df.groupby("CustomerRegion")["CustomerSatisfaction"].mean()
Cust_Sat_Region.sort_values(ascending=False)
# Out:
# CustomerRegion
# East     3.012931
# South    3.008696
# North    2.953488
# West     2.917857
# Name: CustomerSatisfaction, dtype: float64

# %%
# Determine the product in each Category with the highest total revenue.
Catrevenue=df.groupby(["Product","Category"])["TotalRevenue"].sum().reset_index()
Catrevenue1=Catrevenue.loc[Catrevenue.groupby("Category")["TotalRevenue"].idxmax()]
Catrevenue1
# Out:
#     Product         Category  TotalRevenue
# 0   Blender      Accessories         93174
# 21  T-Shirt         Clothing        120533
# 6    Laptop      Electronics        120588
# 7    Laptop  Home Appliances        105949

# %%
# Find the percentage contribution of each region to the total revenue.
regionsale=df.groupby("CustomerRegion")["TotalRevenue"].sum()
Total=df["TotalRevenue"].sum()
# print(Total)
regionsaleper=(regionsale/Total)*100
regionsaleper
# Out:
# CustomerRegion
# East     24.009099
# North    25.621609
# South    24.304647
# West     26.064644
# Name: TotalRevenue, dtype: float64

# %%
# For each Category, calculate the median revenue per order.
cat_median= df.groupby("Category")["TotalRevenue"].median()
cat_median
# Out:
# Category
# Accessories        2520.0
# Clothing           2172.0
# Electronics        2184.0
# Home Appliances    2392.0
# Name: TotalRevenue, dtype: float64

# %%
# Create a pivot table to show the total revenue for each product across regions.
newpivot=df.pivot_table(values="TotalRevenue",
                        index="Product",
                       columns="CustomerRegion",
                       aggfunc="sum")
newpivot
# Out:
# CustomerRegion    East   North   South    West
# Product
# Blender          96455   80372   82401  100836
# Laptop           79703  117787   96388  127481
# Monitor          82071   85719  107607   71969
# Phone            66214  102979   53906  109028
# Sofa             86280   58442   95603   83516
# T-Shirt          94352  133609   99817   85471
# TV              102352   56954   59879   93722
# Watch            62769   79346   82845   55552

# %%
# Create a pivot table showing the average CustomerSatisfaction for each category and region. Date-Based Analysis

pivot2=df.pivot_table(values="CustomerSatisfaction",
                      index="Category",
                     columns="CustomerRegion",
                     aggfunc="mean")

pivot2
# Out:
# CustomerRegion       East     North     South      West
# Category
# Accessories      2.833333  3.108696  2.936170  2.842857
# Clothing         3.080645  2.813333  2.916667  3.075758
# Electronics      3.014706  2.839286  3.164384  2.928571
# Home Appliances  3.092593  3.074074  2.960000  2.837838

# %%
# Calculate the total revenue generated in each month of 2022.
df["Month"]=df["OrderDate"].dt.month
df["Year"]=df["OrderDate"].dt.year
df.head(5)
# Out:
#    OrderID            CustomerName CustomerRegion         Category  Product  \
# 0        1            Michael Lang           East         Clothing  T-Shirt
# 1        2               Tracy Lee           West  Home Appliances       TV
# 2        3              Shawn Lutz          North      Electronics     Sofa
# 3        4             Tonya Price           East      Electronics    Watch
# 4        5  Cynthia Montgomery DDS           East      Electronics    Watch
#
#    Price  Quantity  OrderDate  CustomerSatisfaction  TotalRevenue  Month  Year
# 0    915         5 2022-01-01                     4          4575      1  2022
# 1    549         6 2022-01-02                     4          3294      1  2022
# 2    553         4 2022-01-03                     1          2212      1  2022
# 3    728         9 2022-01-04                     3          6552      1  2022
# 4    320         8 2022-01-05                     5          2560      1  2022

# %%
Year2022=df[df["Year"]==2022]
monthrevenue2022=Year2022.groupby("Month")["TotalRevenue"].sum()
monthrevenue2022
# Out:
# Month
# 1     91974
# 2     85553
# 3     81507
# 4     74519
# 5     88395
# 6     99320
# 7     94364
# 8     94539
# 9     88290
# 10    80525
# 11    81367
# 12    90036
# Name: TotalRevenue, dtype: int32

# %%
# Identify the product with the highest total revenue in the second quarter of 2022.
Quater2022=Year2022[Year2022["Month"].isin([4,5,6])]
highesttotalrevenueQ2=Quater2022.groupby("Product")["TotalRevenue"].sum()
highesttotalrevenueQ2.sort_values(ascending=False).head(1)
# Out:
# Product
# Laptop    47466
# Name: TotalRevenue, dtype: int32

# %%
# Rank all products by their total revenue and display the top 10.
total=df.groupby("Product")["TotalRevenue"].sum().reset_index()
total["Rank"]=total["TotalRevenue"].rank()
total
# Out:
#    Product  TotalRevenue  Rank
# 0  Blender        360064   6.0
# 1   Laptop        421359   8.0
# 2  Monitor        347366   5.0
# 3    Phone        332127   4.0
# 4     Sofa        323841   3.0
# 5  T-Shirt        413249   7.0
# 6       TV        312907   2.0
# 7    Watch        280512   1.0

# %%
# Within each category, rank products by their average CustomerSatisfaction score.
pi=df.groupby(["Product","Category"])["CustomerSatisfaction"].mean().reset_index()
pi["rank"]=pi.groupby("Category")["CustomerSatisfaction"].rank()
pi=pi.sort_values(["Category","rank"])
pi
# Out:
#     Product         Category  CustomerSatisfaction  rank
# 20  T-Shirt      Accessories              2.363636   1.0
# 28    Watch      Accessories              2.608696   2.0
# 4    Laptop      Accessories              2.689655   3.0
# 0   Blender      Accessories              2.806452   4.0
# 8   Monitor      Accessories              2.814815   5.0
# 12    Phone      Accessories              3.071429   6.0
# 16     Sofa      Accessories              3.346154   7.0
# 24       TV      Accessories              3.600000   8.0
# 17     Sofa         Clothing              2.606061   1.0
# 29    Watch         Clothing              2.733333   2.0
# 5    Laptop         Clothing              2.838710   3.0
# 1   Blender         Clothing              2.931034   4.0
# 9   Monitor         Clothing              2.933333   5.0
# 25       TV         Clothing              2.973684   6.0
# 21  T-Shirt         Clothing              3.184211   7.0
# 13    Phone         Clothing              3.441176   8.0
# 22  T-Shirt      Electronics              2.529412   1.0
# 10  Monitor      Electronics              2.700000   2.0
# 6    Laptop      Electronics              2.941176   3.0
# 18     Sofa      Electronics              3.037037   4.0
# 14    Phone      Electronics              3.078947   5.0
# 30    Watch      Electronics              3.128205   6.0
# 26       TV      Electronics              3.142857   7.0
# 2   Blender      Electronics              3.351351   8.0
# 15    Phone  Home Appliances              2.727273   1.0
# 11  Monitor  Home Appliances              2.766667   2.0
# 23  T-Shirt  Home Appliances              2.827586   3.0
# 27       TV  Home Appliances              2.870968   4.0
# 7    Laptop  Home Appliances              2.972222   5.0
# 3   Blender  Home Appliances              3.029412   6.0
# 31    Watch  Home Appliances              3.148148   7.0
# 19     Sofa  Home Appliances              3.461538   8.0

# %%
# Find customers who placed more than 1 orders and calculate their total revenue.
NoOfOrder=df.groupby("CustomerName").agg(NoOfOrder=("OrderID","nunique"),TotalRevenue=("TotalRevenue","sum")).reset_index()
NoOfOrdermore3=NoOfOrder[NoOfOrder["NoOfOrder"]>1]
NoOfOrdermore3
# Out:
#            CustomerName  NoOfOrder  TotalRevenue
# 240         David Brown          2          1449
# 294  Elizabeth Williams          2          5872
# 480        Joshua Davis          2         11202
# 543      Kenneth Taylor          2          4172
# 913        Taylor White          2         10812

# %%
# Identify the category with the highest average revenue per order.
hightest=df.groupby("Category").agg(TotalRevenue=("TotalRevenue","sum"),TotalOrder=("OrderID","nunique")).reset_index()
hightest["Average"]=hightest["TotalRevenue"]/hightest["TotalOrder"]
hightest.sort_values("Average",ascending=False).head(1)
# Out:
#       Category  TotalRevenue  TotalOrder      Average
# 0  Accessories        628335         211  2977.890995

# %%
# Add a column to calculate the profit margin for each product, assuming a 30% profit margin on the price.
df["ProfitMargin"]=df["Price"]*0.30
df
# Out:
#      OrderID            CustomerName CustomerRegion         Category  Product  \
# 0          1            Michael Lang           East         Clothing  T-Shirt
# 1          2               Tracy Lee           West  Home Appliances       TV
# 2          3              Shawn Lutz          North      Electronics     Sofa
# 3          4             Tonya Price           East      Electronics    Watch
# 4          5  Cynthia Montgomery DDS           East      Electronics    Watch
# ..       ...                     ...            ...              ...      ...
# 995      996            Alicia Kelly          North      Electronics   Laptop
# 996      997             David Brown          North         Clothing  Monitor
# 997      998        Michael Martinez           West      Electronics  Blender
# 998      999        Stacey Hines DVM           West  Home Appliances    Phone
# 999     1000           Patrick Lewis           East      Electronics    Watch
#
#      Price  Quantity  OrderDate  CustomerSatisfaction  TotalRevenue  Month  \
# 0      915         5 2022-01-01                     4          4575      1
# 1      549         6 2022-01-02                     4          3294      1
# 2      553         4 2022-01-03                     1          2212      1
# 3      728         9 2022-01-04                     3          6552      1
# 4      320         8 2022-01-05                     5          2560      1
# ..     ...       ...        ...                   ...           ...    ...
# 995    983         9 2024-09-22                     1          8847      9
# 996    313         1 2024-09-23                     4           313      9
# 997    754         6 2024-09-24                     5          4524      9
# 998    475         9 2024-09-25                     5          4275      9
# 999    843         1 2024-09-26                     1           843      9
#
#      Year  ProfitMargin
# 0    2022         274.5
# 1    2022         164.7
# 2    2022         165.9
# 3    2022         218.4
# 4    2022          96.0
# ..    ...           ...
# 995  2024         294.9
# 996  2024          93.9
# 997  2024         226.2
# 998  2024         142.5
# 999  2024         252.9
#
# [1000 rows x 13 columns]

# %%
# Determine the product that has the highest average revenue per order, grouped by region.
hightest1=df.groupby(["Category","CustomerRegion"]).agg(
    TotalRevenue=("TotalRevenue","sum"),
    TotalOrder=("OrderID","nunique")
).reset_index()


hightest1["Average"]=hightest1["TotalRevenue"]/hightest1["TotalOrder"]

hightest1_idx=hightest1.groupby("CustomerRegion")["Average"].idxmax()


hightest1_result = hightest1.iloc[hightest1_idx]

hightest1_result
# Out:
#            Category CustomerRegion  TotalRevenue  TotalOrder      Average
# 0       Accessories           East        152252          48  3171.916667
# 1       Accessories          North        134315          46  2919.891304
# 14  Home Appliances          South        153596          50  3071.920000
# 3       Accessories           West        202463          70  2892.328571

# %%
# Find the most frequently ordered product for each region.

data=df.groupby(["Product","CustomerRegion"])["OrderID"].nunique().reset_index()
Highest_indx=data.groupby("CustomerRegion")["OrderID"].idxmax()
Highest_product_region=data.iloc[Highest_indx]
Highest_product_region
# Out:
#     Product CustomerRegion  OrderID
# 0   Blender           East       37
# 5    Laptop          North       40
# 18     Sofa          South       35
# 27       TV           West       43

# %%
# Calculate the rolling 7-day average revenue for the entire dataset.
df["RollingAvg"]=df["TotalRevenue"].rolling(window=7).mean()
df.head(10)
